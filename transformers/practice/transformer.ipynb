# %% [markdown]
# <a href="https://colab.research.google.com/github/wheres-my-data/ai-engineering/blob/main/transformers/practice/transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Tokenization**
#
# *   Word Level Tokenization
# *   Character Level Tokenization
# *   Sub Word Level Tokenization

# %%
import tiktoken
